# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
# jpg, png -----> numpy array

# %%
image_as_array = mpimg.imread('../DATA/palm_trees.jpg')

# %%
image_as_array.shape # (H, W, C)
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_as_array)

# %%
# (H,W,C) -----> 2d(H*W,C)

# %%
(h,w,c) = image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array_2d = image_as_array.reshape(h*w,c)

# %%
image_as_array_2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array_2d)

# %%
model.cluster_centers_
# Out:
# array([[  2.74013786,   2.55876285,   3.68231031],
#        [138.65751748, 144.32360614, 143.34445087],
#        [193.85134272, 154.5281607 , 106.92069462],
#        [ 71.48825263, 109.53349966, 137.80418413],
#        [219.27462343, 134.31505531,  45.02751142],
#        [ 67.01114403,  61.34383932,  61.84324934]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [139, 144, 143],
#        [194, 155, 107],
#        [ 71, 110, 138],
#        [219, 134,  45],
#        [ 67,  61,  62]])

# %%
rgb_codes[labels]
# Out:
# array([[ 71, 110, 138],
#        [ 71, 110, 138],
#        [ 71, 110, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h,w,c))

# %%
plt.imshow(quantized_image)
